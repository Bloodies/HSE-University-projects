# %% [markdown]
# <a href="https://colab.research.google.com/github/Bloodies/HSE-University-projects/blob/Bloodies/Course-4/Internet-technology/Task-2/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Course-4/Internet-technology/Task-2/Task_2.ipynb

# %%
import requests
import re
from pprint import pprint
from bs4 import BeautifulSoup

# %%
api_key = r""

url_1 = r"https://ru.wikipedia.org/w/index.php?title=JSON&action=history"
url_2 = r"https://api.hh.ru/vacancies?industry=7&per_page=10&page=0"
url_3 = r"https://www.booking.com/searchresults.ru.html?label=gen173nr-1FCAEoggI46AdIM1gEaMIBiAEBmAEhuAEXyAEU2AEB6AEB-AELiAIBqAIDuAKgxYXuBcACAQ&sid=b0c2a5b4628d057418075944d1c841aa&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.ru.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaMIBiAEBmAEhuAEXyAEU2AEB6AEB-AELiAIBqAIDuAKgxYXuBcACAQ%3Bsid%3Db0c2a5b4628d057418075944d1c841aa%3Bsb_price_type%3Dtotal%3Bsig%3Dv1WePBgz9l%26%3B&ss=%D0%9F%D0%B5%D1%80%D0%BC%D1%8C%2C+%D0%9F%D0%B5%D1%80%D0%BC%D1%81%D0%BA%D0%B8%D0%B9+%D0%BA%D1%80%D0%B0%D0%B9%2C+%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D1%8F&is_ski_area=&checkin_year=2021&checkin_month=10&checkin_monthday=23&checkout_year=2021&checkout_month=10&checkout_monthday=24&group_adults=1&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=gthvm&ac_position=0&ac_langcode=ru&ac_click_type=b&dest_id=-2980155&dest_type=city&iata=PEE&place_id_lat=58.01496&place_id_lon=56.24672&search_pageview_id=94f68390509b007e&search_selected=true&search_pageview_id=94f68390509b007e&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'}

# %%
regex = r'(?<!:)([0-9a-fA-F]{4}(:[0-9a-fA-F]{4}){7})(?!:)|(\b(?:(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)(?:\.|$)){4}\b)'
reg = re.compile(regex)

request = requests.get(url_1, headers=headers)
soup = BeautifulSoup(request.text, "html.parser")

ip_list = []
country = []
tree_elements = soup.find_all('span', class_='history-user')

print("Парсинг сайта")
for element in tree_elements:
    match = re.search(regex, element.find('a', class_='mw-userlink').get_text().strip())
    if match is not None:
        # print(match.group())
        ip_list.append(match.group())

# print(ip_list)
# print(set(ip_list))
print("Поиск стран по ip")
for ip in set(ip_list):
    request = requests.get(r"http://api.ipstack.com/" + ip + "?access_key=" + api_key)
    obj = request.json()
    # print(obj["country_name"])
    country.append(obj["country_name"])

print("---------------")
dictionary = {i: country.count(i) for i in country}
for w in sorted(dictionary, key=dictionary.get, reverse=True):
    print(w, dictionary[w])
# Out:
# Парсинг сайта
# Поиск стран по ip
# ---------------
# Russia 9
# Belarus 3
# Kazakhstan 1
# Thailand 1
# Ukraine 1
# Germany 1

# %%
request = requests.get(url_2)
pprint(request.json())
# Out:
# {'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&industry=7&items_on_page=10',
#  'arguments': None,
#  'clusters': None,
#  'found': 136646,
#  'items': [{'accept_temporary': False,
#             'address': None,
#             'alternate_url': 'https://hh.ru/vacancy/48563224',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48563224',
#             'archived': False,
#             'area': {'id': '1',
#                      'name': 'Москва',
#                      'url': 'https://api.hh.ru/areas/1'},
#             'contacts': None,
#             'created_at': '2021-10-06T11:34:52+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/731261',
#                          'id': '731261',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3452326.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/3452325.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/752841.png'},
#                          'name': 'Fortex Group',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/731261',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=731261'},
#             'has_test': False,
#             'id': '48563224',
#             'insider_interview': None,
#             'name': 'Менеджер проекта',
#             'premium': False,
#             'published_at': '2021-10-06T11:34:52+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': None,
#                        'gross': False,
#                        'to': 200000},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': None,
#                         'responsibility': 'Обработка входящих заявок/лидов от '
#                                           'наших клиентов. Подбор пула '
#                                           'подходящих предложений из нашей '
#                                           'базы. Проведение показов на '
#                                           'объекте, переговоры, заключение...'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48563224?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': {'building': '82/4А',
#                         'city': 'Ростов-на-Дону',
#                         'description': None,
#                         'id': '6096317',
#                         'lat': 47.235393,
#                         'lng': 39.714267,
#                         'metro': None,
#                         'metro_stations': [],
#                         'raw': 'Ростов-на-Дону, Ворошиловский проспект, 82/4А',
#                         'street': 'Ворошиловский проспект'},
#             'alternate_url': 'https://hh.ru/vacancy/47726656',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47726656',
#             'archived': False,
#             'area': {'id': '76',
#                      'name': 'Ростов-на-Дону',
#                      'url': 'https://api.hh.ru/areas/76'},
#             'contacts': None,
#             'created_at': '2021-10-06T12:42:19+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/1906008',
#                          'id': '1906008',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3917796.jpeg',
#                                        '90': 'https://hhcdn.ru/employer-logo/3917795.jpeg',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/869230.jpg'},
#                          'name': 'Инновационные системы менеджмента',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/1906008',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1906008'},
#             'has_test': False,
#             'id': '47726656',
#             'insider_interview': None,
#             'name': 'Сотрудник контакт-центра (без продаж)',
#             'premium': False,
#             'published_at': '2021-10-06T12:42:19+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 20000,
#                        'gross': False,
#                        'to': None},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': 'От тебя: ✔️ Важно желание обучаться и '
#                                        'постоянно повышать свою квалификацию. '
#                                        '✔️ Энергичность и позитивный настрой '
#                                        'на работу. ✔️ Грамотная устная и '
#                                        'письменная...',
#                         'responsibility': 'Консультировать будущих клиентов '
#                                           'компании. ✔️ Проводить '
#                                           'идентификацию клиентов согласно '
#                                           'установленным стандартам.'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/47726656?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': True,
#             'address': None,
#             'alternate_url': 'https://hh.ru/vacancy/48897698',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48897698',
#             'archived': False,
#             'area': {'id': '78',
#                      'name': 'Самара',
#                      'url': 'https://api.hh.ru/areas/78'},
#             'contacts': None,
#             'created_at': '2021-10-17T13:20:42+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/4053225',
#                          'id': '4053225',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3531944.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/3531943.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/772763.png'},
#                          'name': 'HR.Vision',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/4053225',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4053225'},
#             'has_test': False,
#             'id': '48897698',
#             'insider_interview': None,
#             'name': 'Менеджер по развитию продаж (b2b cегмент, EdTech рынок, '
#                     'удалённо)',
#             'premium': False,
#             'published_at': '2021-10-17T13:20:42+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 60000,
#                        'gross': False,
#                        'to': 80000},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': 'Productstar. Онлайн образование. 4 '
#                                        'года на рынке. 5000+ выпускников. 10х '
#                                        'рост в 2020 году. 50 человек штат. ',
#                         'responsibility': 'Онлайн обучение сотрудников '
#                                           'среднего и крупного бизнеса. '
#                                           'Направления Продакт менеджмент, '
#                                           'Аналитика, Маркетинг. '
#                                           'Индивидуальная программа для '
#                                           'каждого заказчика. Работа на '
#                                           'дому. '},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48897698?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': None,
#             'alternate_url': 'https://hh.ru/vacancy/48449376',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48449376',
#             'archived': False,
#             'area': {'id': '1803',
#                      'name': 'Торжок',
#                      'url': 'https://api.hh.ru/areas/1803'},
#             'contacts': None,
#             'created_at': '2021-10-01T18:24:18+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/813481',
#                          'id': '813481',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1260302.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/1260301.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/119478.png'},
#                          'name': 'Группа Компаний БРИО',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/813481',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=813481'},
#             'has_test': False,
#             'id': '48449376',
#             'insider_interview': None,
#             'name': 'Оператор поточной линии производства древесных материалов',
#             'premium': False,
#             'published_at': '2021-10-01T18:24:18+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 40000,
#                        'gross': False,
#                        'to': None},
#             'schedule': {'id': 'shift', 'name': 'Сменный график'},
#             'snippet': {'requirement': 'Среднее профессиональное (техническое) '
#                                        'образование. Опыт работы на '
#                                        'производстве от 3 лет. Владение '
#                                        'компьютером.',
#                         'responsibility': 'Управление технологическим '
#                                           'процессом, обеспечение '
#                                           'бесперебойной работы линии. '
#                                           'Настройка параметров линии на '
#                                           'производство требуемой продукции. '
#                                           'Участие в ремонте и обслуживании '
#                                           'линии. '},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48449376?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': {'building': '6с16',
#                         'city': 'Москва',
#                         'description': None,
#                         'id': '4718900',
#                         'lat': 55.693505,
#                         'lng': 37.660548,
#                         'metro': None,
#                         'metro_stations': [],
#                         'raw': 'Москва, Проектируемый проезд № 4062, 6с16',
#                         'street': 'Проектируемый проезд № 4062'},
#             'alternate_url': 'https://hh.ru/vacancy/48367726',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48367726',
#             'archived': False,
#             'area': {'id': '1',
#                      'name': 'Москва',
#                      'url': 'https://api.hh.ru/areas/1'},
#             'contacts': None,
#             'created_at': '2021-09-29T13:14:06+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/4053225',
#                          'id': '4053225',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3531944.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/3531943.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/772763.png'},
#                          'name': 'HR.Vision',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/4053225',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4053225'},
#             'has_test': False,
#             'id': '48367726',
#             'insider_interview': None,
#             'name': 'Менеджер по продажам',
#             'premium': False,
#             'published_at': '2021-09-29T13:14:06+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 75823,
#                        'gross': False,
#                        'to': 130490},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': 'Знания и умение применять техники '
#                                        'продаж. Готовность к объемам '
#                                        'ежедневных операций. Желателен опыт в '
#                                        'продажах консалтинга, услуг для '
#                                        'бизнеса.',
#                         'responsibility': 'Процесс продажи: 1. Холодные '
#                                           'клиенты. Звонки по готовой базе '
#                                           'юр.лиц напрямую - владельцу бизнеса '
#                                           '(ЛПР). Такая база дает нам '
#                                           'пополнять ряды...'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48367726?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': None,
#             'alternate_url': 'https://hh.ru/vacancy/48792827',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48792827',
#             'archived': False,
#             'area': {'id': '19',
#                      'name': 'Брянск',
#                      'url': 'https://api.hh.ru/areas/19'},
#             'contacts': None,
#             'created_at': '2021-10-13T11:27:47+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/3615039',
#                          'id': '3615039',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2722326.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/2722325.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/570214.png'},
#                          'name': 'Энтера',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/3615039',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3615039'},
#             'has_test': False,
#             'id': '48792827',
#             'insider_interview': None,
#             'name': 'Менеджер по продажам (удалённо)',
#             'premium': False,
#             'published_at': '2021-10-13T11:27:47+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 60000,
#                        'gross': False,
#                        'to': 116000},
#             'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#             'snippet': {'requirement': 'Опыт в продажах от 1 года. — Умение '
#                                        'добиваться результата. — Желание '
#                                        'развиваться сфере продаж B2B на самом '
#                                        'высоком уровне.',
#                         'responsibility': 'Активные продажи по входящим '
#                                           'обращениям.'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48792827?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': None,
#             'alternate_url': 'https://hh.ru/vacancy/48953026',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48953026',
#             'archived': False,
#             'area': {'id': '88',
#                      'name': 'Казань',
#                      'url': 'https://api.hh.ru/areas/88'},
#             'contacts': None,
#             'created_at': '2021-10-19T09:40:38+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/3615039',
#                          'id': '3615039',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2722326.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/2722325.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/570214.png'},
#                          'name': 'Энтера',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/3615039',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3615039'},
#             'has_test': False,
#             'id': '48953026',
#             'insider_interview': None,
#             'name': 'Менеджер по продажам (удалённо)',
#             'premium': False,
#             'published_at': '2021-10-19T09:40:38+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 60000,
#                        'gross': False,
#                        'to': 116000},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': 'Опыт в продажах от 1 года. — Умение '
#                                        'добиваться результата. — Желание '
#                                        'развиваться сфере продаж B2B на самом '
#                                        'высоком уровне.',
#                         'responsibility': 'Активные продажи по входящим '
#                                           'обращениям.'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48953026?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': {'building': '5с1',
#                         'city': 'Москва',
#                         'description': None,
#                         'id': '6290117',
#                         'lat': 55.786602,
#                         'lng': 37.72352,
#                         'metro': {'lat': 55.783096,
#                                   'line_id': '3',
#                                   'line_name': 'Арбатско-Покровская',
#                                   'lng': 37.719289,
#                                   'station_id': '3.130',
#                                   'station_name': 'Семеновская'},
#                         'metro_stations': [{'lat': 55.783096,
#                                             'line_id': '3',
#                                             'line_name': 'Арбатско-Покровская',
#                                             'lng': 37.719289,
#                                             'station_id': '3.130',
#                                             'station_name': 'Семеновская'}],
#                         'raw': 'Москва, Ткацкая улица, 5с1',
#                         'street': 'Ткацкая улица'},
#             'alternate_url': 'https://hh.ru/vacancy/48616891',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48616891',
#             'archived': False,
#             'area': {'id': '1',
#                      'name': 'Москва',
#                      'url': 'https://api.hh.ru/areas/1'},
#             'contacts': None,
#             'created_at': '2021-10-07T15:59:51+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/2209533',
#                          'id': '2209533',
#                          'logo_urls': None,
#                          'name': 'АйБиКонсалт',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/2209533',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2209533'},
#             'has_test': False,
#             'id': '48616891',
#             'insider_interview': None,
#             'name': 'Менеджер по продажам в интернет-портал о бизнесе и '
#                     'компаниях России',
#             'premium': False,
#             'published_at': '2021-10-07T15:59:51+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 80000,
#                        'gross': False,
#                        'to': 120000},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': '7 лет успешной работы. Опыт работы в '
#                                        'b2b от 1 года. Опыт работы с первыми '
#                                        'лицами компаний клиентов. ',
#                         'responsibility': 'Работа с теплыми клиентами '
#                                           '(входящие звонки и заявки, текущие '
#                                           'клиенты, зарегистрированные '
#                                           'пользователи). . «Холодный поиск» '
#                                           'предусмотрен системой мотивации, но '
#                                           'не является...'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48616891?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': {'building': '25',
#                         'city': 'Казань',
#                         'description': None,
#                         'id': '1260922',
#                         'lat': 55.790119,
#                         'lng': 49.106845,
#                         'metro': {'lat': 55.795206,
#                                   'line_id': '49',
#                                   'line_name': 'Центральная',
#                                   'lng': 49.105426,
#                                   'station_id': '49.272',
#                                   'station_name': 'Кремлевская'},
#                         'metro_stations': [{'lat': 55.795206,
#                                             'line_id': '49',
#                                             'line_name': 'Центральная',
#                                             'lng': 49.105426,
#                                             'station_id': '49.272',
#                                             'station_name': 'Кремлевская'}],
#                         'raw': 'Казань, Московская улица, 25',
#                         'street': 'Московская улица'},
#             'alternate_url': 'https://hh.ru/vacancy/47514106',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47514106',
#             'archived': False,
#             'area': {'id': '88',
#                      'name': 'Казань',
#                      'url': 'https://api.hh.ru/areas/88'},
#             'contacts': None,
#             'created_at': '2021-09-27T11:27:41+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/1144429',
#                          'id': '1144429',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1409362.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/1409361.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/241671.png'},
#                          'name': 'Рефакт +',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/1144429',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1144429'},
#             'has_test': False,
#             'id': '47514106',
#             'insider_interview': None,
#             'name': 'Менеджер по продажам интернет услуг (менеджер теплых '
#                     'продаж)',
#             'premium': False,
#             'published_at': '2021-09-27T11:27:41+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 45000,
#                        'gross': True,
#                        'to': None},
#             'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#             'snippet': {'requirement': 'Опыт в продажах (опыт продажи рекламы '
#                                        'будет сильным преимуществом). '
#                                        'Готовность много разговаривать с '
#                                        'клиентами. Готовность подробно изучить '
#                                        'специфику продукта (список...',
#                         'responsibility': 'Контекстная реклама: Яндекс.Директ, '
#                                           'Google Ads. SMM: продвижение в VK, '
#                                           'Instagram, Facebook. Создание '
#                                           'сайтов: Landing Page, корпоративные '
#                                           'сайты, интернет-магазины. '},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/47514106?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [],
#             'working_time_modes': []},
#            {'accept_temporary': False,
#             'address': None,
#             'alternate_url': 'https://hh.ru/vacancy/48315705',
#             'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48315705',
#             'archived': False,
#             'area': {'id': '43',
#                      'name': 'Калуга',
#                      'url': 'https://api.hh.ru/areas/43'},
#             'contacts': None,
#             'created_at': '2021-09-28T09:02:09+0300',
#             'department': None,
#             'employer': {'alternate_url': 'https://hh.ru/employer/2095217',
#                          'id': '2095217',
#                          'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3541032.png',
#                                        '90': 'https://hhcdn.ru/employer-logo/3541031.png',
#                                        'original': 'https://hhcdn.ru/employer-logo-original/775035.png'},
#                          'name': 'ЛДМ и Ко',
#                          'trusted': True,
#                          'url': 'https://api.hh.ru/employers/2095217',
#                          'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2095217'},
#             'has_test': False,
#             'id': '48315705',
#             'insider_interview': None,
#             'name': 'Тестировщик онлайн-игры',
#             'premium': False,
#             'published_at': '2021-09-28T09:02:09+0300',
#             'relations': [],
#             'response_letter_required': False,
#             'response_url': None,
#             'salary': {'currency': 'RUR',
#                        'from': 30000,
#                        'gross': False,
#                        'to': None},
#             'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#             'snippet': {'requirement': None,
#                         'responsibility': 'Проводим тестирование Онлайн-игры '
#                                           'Axie Infinity.'},
#             'sort_point_distance': None,
#             'type': {'id': 'open', 'name': 'Открытая'},
#             'url': 'https://api.hh.ru/vacancies/48315705?host=hh.ru',
#             'working_days': [],
#             'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#                                         'name': 'Можно работать сменами по\xa0'
#                                                 '4–6 часов в\xa0день'}],
#             'working_time_modes': [{'id': 'start_after_sixteen',
#                                     'name': 'Можно начинать работать после '
#                                             '16:00'}]}],
#  'page': 0,
#  'pages': 200,
#  'per_page': 10}

# %%
while True:

    request = requests.get(url_3, headers=headers)
    soup = BeautifulSoup(request.content, "html.parser")

    hotelBlock = soup.find_all("div", {"class": "sr_item"})

    i = 0
    for hotel in hotelBlock:
        hotelName = hotel.find("span", {"class": "sr-hotel__name"}).get_text().strip()
        print(hotelName)

        print("\n Элементов на странице:" + " " + str(len(hotelBlock)))

        nextPage = soup.find("a", title="Next page")
        if nextPage is None:
            nextPage = soup.find("a", title="Следующая страница")

        if nextPage is not None:
            url = "https://www.booking.com/" + nextPage.attrs["href"]
            print("Обработка следующей страницы... \n")
        else:
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d081312a6df1> in <module>()
#       1 while True:
#       2
# ----> 3     request = requests.get(url_3, headers=headers)
#       4     soup = BeautifulSoup(request.content, "html.parser")
#       5
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     490         """
#     491         if self.chunked and self.supports_chunked_reads():
# --> 492             for line in self.read_chunked(amt, decode_content=decode_content):
#     493                 yield line
#     494         else:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     666
#     667             while True:
# --> 668                 self._update_chunk_length()
#     669                 if self.chunk_left == 0:
#     670                     break
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     598         if self.chunk_left is not None:
#     599             return
# --> 600         line = self._fp.fp.readline()
#     601         line = line.split(b';', 1)[0]
#     602         try:
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
